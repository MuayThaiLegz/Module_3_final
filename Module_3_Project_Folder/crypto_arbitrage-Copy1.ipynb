# %% [markdown]
# ## Crypto Arbitrage
#
# In this Challenge, you'll take on the role of an analyst at a high-tech investment firm. The vice president (VP) of your department is considering arbitrage opportunities in Bitcoin and other cryptocurrencies. As Bitcoin trades on markets across the globe, can you capitalize on simultaneous price dislocations in those markets by using the powers of Pandas?
#
# For this assignment, you’ll sort through historical trade data for Bitcoin on two exchanges: Bitstamp and Coinbase. Your task is to apply the three phases of financial analysis to determine if any arbitrage opportunities exist for Bitcoin.
#
# This aspect of the Challenge will consist of 3 phases.
#
# 1. Collect the data.
#
# 2. Prepare the data.
#
# 3. Analyze the data.

# %% [markdown]
# ###  Import the required libraries and dependencies.

# %%
import pandas as pd
from pathlib import Path
# %matplotlib inline

# %% [markdown]
# ## Collect the Data
#
# To collect the data that you’ll need, complete the following steps:
#
# Instructions.
#
# 1. Using the Pandas `read_csv` function and the `Path` module, import the data from `bitstamp.csv` file, and create a DataFrame called `bitstamp`. Set the DatetimeIndex as the Timestamp column, and be sure to parse and format the dates.
#
# 2. Use the `head` (and/or the `tail`) function to confirm that Pandas properly imported the data.
#
# 3. Repeat Steps 1 and 2 for `coinbase.csv` file.

# %% [markdown]
# ### Step 1: Using the Pandas `read_csv` function and the `Path` module, import the data from `bitstamp.csv` file, and create a DataFrame called `bitstamp`. Set the DatetimeIndex as the Timestamp column, and be sure to parse and format the dates.

# %%
# Read in the CSV file called "bitstamp.csv" using the Path module. 
# The CSV file is located in the Resources folder.
# Set the index to the column "Date"
# Set the parse_dates and infer_datetime_format parameters

bitstamp_df = pd.read_csv(
    Path('./Resources/bitstamp.csv'),
    index_col="Timestamp", 
    parse_dates=True, 
    infer_datetime_format=True
)
"""
Collect the Data:

Uses the Pandas `read_csv` function and the `Path` module, import the data from `bitstamp.csv` file, and create a DataFrame called `bitstamp`    
    
    Args:
    
        Path(window path): Read in the CSV file called "bitstamp.csv" using the Path module.
        
    Sets:
        The index to the column "Date".
        
        The parse_dates and infer_datetime_format parameters.
        """
# Out:
# '\nCollect the Data:\n\nUses the Pandas `read_csv` function and the `Path` module, import the data from `bitstamp.csv` file, and create a DataFrame called `bitstamp`    \n    \n    Args:\n    \n        Path(window path): Read in the CSV file called "bitstamp.csv" using the Path module.\n        \n    Sets:\n        The index to the column "Date".\n        \n        The parse_dates and infer_datetime_format parameters.\n        '

# %%
# Looks at fire 5 rows in dataframe

bitstamp_df.head()
# Out:
#                        Open    High     Low    Close  BTC Volume   USD Volume  \
# Timestamp
# 2015-12-31 19:01:00  430.89  430.89  430.89  $430.89    0.080631    34.743096
# 2015-12-31 19:02:00  430.89  430.89  430.89  $430.89    0.143257    61.728095
# 2015-12-31 19:03:00     NaN     NaN     NaN     $nan         NaN          NaN
# 2015-12-31 19:04:00  430.19  431.06  430.19  $431.06    1.032161   444.627575
# 2015-12-31 19:05:00  431.06  432.11  430.21  $430.54    5.558156  2397.461993
#
#                      Weighted Price
# Timestamp
# 2015-12-31 19:01:00      430.890000
# 2015-12-31 19:02:00      430.890000
# 2015-12-31 19:03:00             NaN
# 2015-12-31 19:04:00      430.773269
# 2015-12-31 19:05:00      431.341280

# %%
# Gives the total count of values for each column.

bitstamp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1588619 entries, 2015-12-31 19:01:00 to 2019-01-07 23:59:00
# Data columns (total 7 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   Open            1350419 non-null  float64
#  1   High            1350419 non-null  float64
#  2   Low             1350419 non-null  float64
#  3   Close           1588619 non-null  object
#  4   BTC Volume      1350419 non-null  float64
#  5   USD Volume      1350419 non-null  float64
#  6   Weighted Price  1350419 non-null  float64
# dtypes: float64(6), object(1)
# memory usage: 97.0+ MB

# %% [markdown]
# ### Step 2: Use the `head` (and/or the `tail`) function to confirm that Pandas properly imported the data.

# %%
# Use the head (and/or tail) function to confirm that the data was imported properly.
# YOUR CODE HERE

bitstamp_df.tail()
# Out:
#                         Open     High      Low     Close  BTC Volume  \
# Timestamp
# 2019-01-07 23:55:00  3977.81  3977.81  3977.81  $3977.81    0.008042
# 2019-01-07 23:56:00      NaN      NaN      NaN      $nan         NaN
# 2019-01-07 23:57:00  3977.81  3984.40  3977.81   $3984.4    8.907403
# 2019-01-07 23:58:00  3980.97  3980.97  3980.97  $3980.97    1.615929
# 2019-01-07 23:59:00  3979.07  3983.52  3979.07  $3983.52    1.920004
#
#                        USD Volume  Weighted Price
# Timestamp
# 2019-01-07 23:55:00     31.988752     3977.810000
# 2019-01-07 23:56:00           NaN             NaN
# 2019-01-07 23:57:00  35464.870894     3981.504964
# 2019-01-07 23:58:00   6432.963358     3980.970000
# 2019-01-07 23:59:00   7643.937878     3981.209496

# %% [markdown]
# ### Step 3: Repeat Steps 1 and 2 for `coinbase.csv` file.

# %%
# Read in the CSV file called "coinbase.csv" using the Path module. 
# The CSV file is located in the Resources folder.
# Set the index to the column "Timestamp"
# Set the parse_dates and infer_datetime_format parameters

coinbase_df = pd.read_csv(
    Path('./Resources/coinbase.csv'),
    index_col="Timestamp", 
    parse_dates=True, 
    infer_datetime_format=True
)
"""
Uses the Pandas `read_csv` function and the `Path` module, import the data from `coinbase.csv` file, and create a DataFrame called `bitstamp`    
    
    Args:
        Path(window path): Read in the CSV file called "bitstamp.csv" using the Path module.
        
    Sets:
        The index to the column "Date".
        
        The parse_dates and infer_datetime_format parameters.
        """
# Out:
# '\nUses the Pandas `read_csv` function and the `Path` module, import the data from `coinbase.csv` file, and create a DataFrame called `bitstamp`    \n    \n    Args:\n        Path(window path): Read in the CSV file called "bitstamp.csv" using the Path module.\n        \n    Sets:\n        The index to the column "Date".\n        \n        The parse_dates and infer_datetime_format parameters.\n        '

# %%
# Looks at fire 5 rows in dataframe

coinbase_df.head()
# Out:
#                        Open    High     Low    Close  BTC Volume   USD Volume  \
# Timestamp
# 2015-12-31 19:01:00  430.38  430.40  430.38   $430.4    0.947800   407.924370
# 2015-12-31 19:02:00  430.40  430.40  430.40   $430.4    1.633400   703.015360
# 2015-12-31 19:03:00  430.39  430.39  430.36  $430.36   12.566300  5408.313368
# 2015-12-31 19:04:00  430.39  430.39  430.39  $430.39    1.953000   840.551670
# 2015-12-31 19:05:00  430.40  430.96  430.40  $430.96   12.114161  5216.297064
#
#                      Weighted Price
# Timestamp
# 2015-12-31 19:01:00      430.390768
# 2015-12-31 19:02:00      430.400000
# 2015-12-31 19:03:00      430.382322
# 2015-12-31 19:04:00      430.390000
# 2015-12-31 19:05:00      430.595001

# %%
# Gives the total count of values for each column.

coinbase_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1588206 entries, 2015-12-31 19:01:00 to 2019-01-07 17:06:00
# Data columns (total 7 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   Open            1550147 non-null  float64
#  1   High            1550147 non-null  float64
#  2   Low             1550147 non-null  float64
#  3   Close           1588206 non-null  object
#  4   BTC Volume      1550147 non-null  float64
#  5   USD Volume      1550147 non-null  float64
#  6   Weighted Price  1550147 non-null  float64
# dtypes: float64(6), object(1)
# memory usage: 96.9+ MB

# %%
# Use the head (and/or tail) function to confirm that the data was imported properly.
# YOUR CODE HERE
coinbase_df.tail()
# Out:
#                         Open     High      Low     Close  BTC Volume  \
# Timestamp
# 2019-01-07 17:02:00  4006.01  4006.57  4006.00  $4006.01    3.382954
# 2019-01-07 17:03:00  4006.01  4006.57  4006.00  $4006.01    0.902164
# 2019-01-07 17:04:00  4006.01  4006.01  4006.00  $4006.01    1.192123
# 2019-01-07 17:05:00  4006.01  4006.01  4005.50   $4005.5    2.699700
# 2019-01-07 17:06:00  4005.51  4006.01  4005.51  $4005.99    1.752778
#
#                        USD Volume  Weighted Price
# Timestamp
# 2019-01-07 17:02:00  13553.433078     4006.390309
# 2019-01-07 17:03:00   3614.083169     4006.017233
# 2019-01-07 17:04:00   4775.647308     4006.003635
# 2019-01-07 17:05:00  10814.241898     4005.719991
# 2019-01-07 17:06:00   7021.183546     4005.745614

# %% [markdown]
# ## Prepare the Data
#
# To prepare and clean your data for analysis, complete the following steps:
#
# 1. For the bitstamp DataFrame, replace or drop all `NaN`, or missing, values in the DataFrame.
#
# 2. Use the `str.replace` function to remove the dollar signs ($) from the values in the Close column.
#
# 3. Convert the data type of the Close column to a `float`.
#
# 4. Review the data for duplicated values, and drop them if necessary.
#
# 5. Repeat Steps 1–4 for the coinbase DataFrame.

# %% [markdown]
# ### Step 1: For the bitstamp DataFrame, replace or drop all `NaN`, or missing, values in the DataFrame.

# %%
# Checking total vaules of NaN or missing before drop.

bitstamp_df.isnull().sum()
# Out:
# Open              238200
# High              238200
# Low               238200
# Close                  0
# BTC Volume        238200
# USD Volume        238200
# Weighted Price    238200
# dtype: int64

# %%
# For the bitstamp DataFrame, replace or drop all NaNs or missing values in the DataFrame
# YOUR CODE HERE

bitstamp_df.dropna(inplace=True)

# %%
# Checking that the drop has been completed 

bitstamp_df.isnull().sum()
# Out:
# Open              0
# High              0
# Low               0
# Close             0
# BTC Volume        0
# USD Volume        0
# Weighted Price    0
# dtype: int64

# %%
# Looking at our updated dataframe

bitstamp_df.head()
# Out:
#                        Open    High     Low    Close  BTC Volume   USD Volume  \
# Timestamp
# 2015-12-31 19:01:00  430.89  430.89  430.89  $430.89    0.080631    34.743096
# 2015-12-31 19:02:00  430.89  430.89  430.89  $430.89    0.143257    61.728095
# 2015-12-31 19:04:00  430.19  431.06  430.19  $431.06    1.032161   444.627575
# 2015-12-31 19:05:00  431.06  432.11  430.21  $430.54    5.558156  2397.461993
# 2015-12-31 19:06:00  432.53  432.53  431.48  $432.52    4.117318  1776.650476
#
#                      Weighted Price
# Timestamp
# 2015-12-31 19:01:00      430.890000
# 2015-12-31 19:02:00      430.890000
# 2015-12-31 19:04:00      430.773269
# 2015-12-31 19:05:00      431.341280
# 2015-12-31 19:06:00      431.506725

# %% [markdown]
# ### Step 2: Use the `str.replace` function to remove the dollar signs ($) from the values in the Close column.

# %%
# Use the str.replace function to remove the dollar sign, $
# YOUR CODE HERE

bitstamp_df["Close"] = bitstamp_df["Close"].str.replace("$", "")
bitstamp_df["Close"].dtype
# Out:
# dtype('O')

# %% [markdown]
# ### Step 3: Convert the data type of the Close column to a `float`.

# %%
# Convert the Close data type to a float
# YOUR CODE HERE

bitstamp_df["Close"] = bitstamp_df["Close"].astype("float")
bitstamp_df["Close"].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Step 4: Review the data for duplicated values, and drop them if necessary.

# %%
# Review the data for duplicate values, and drop them if necessary
# YOUR CODE HERE
# Number of duplicate values before the drop.

bitstamp_df.duplicated().sum()
# Out:
# 2647

# %%
# Removing duplicates

bitstamp_df.drop_duplicates(inplace=True)

# %%
# Checking that the drop has been completed 

bitstamp_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Step 5: Repeat Steps 1–4 for the coinbase DataFrame.

# %%
# Repeat Steps 1–4 for the coinbase DataFrame
# YOUR CODE HERE
coinbase_df.isnull().sum()
# Out:
# Open              38059
# High              38059
# Low               38059
# Close                 0
# BTC Volume        38059
# USD Volume        38059
# Weighted Price    38059
# dtype: int64

# %%
# For the coinbase DataFrame, replace or drop all NaNs or missing values in the DataFrame
# YOUR CODE HERE
coinbase_df.dropna(inplace=True)

# %%
# Checking that the drop has been completed 

coinbase_df.isnull().sum()
# Out:
# Open              0
# High              0
# Low               0
# Close             0
# BTC Volume        0
# USD Volume        0
# Weighted Price    0
# dtype: int64

# %%
# Looking at our updated dataframe

coinbase_df.head()
# Out:
#                        Open    High     Low    Close  BTC Volume   USD Volume  \
# Timestamp
# 2015-12-31 19:01:00  430.38  430.40  430.38   $430.4    0.947800   407.924370
# 2015-12-31 19:02:00  430.40  430.40  430.40   $430.4    1.633400   703.015360
# 2015-12-31 19:03:00  430.39  430.39  430.36  $430.36   12.566300  5408.313368
# 2015-12-31 19:04:00  430.39  430.39  430.39  $430.39    1.953000   840.551670
# 2015-12-31 19:05:00  430.40  430.96  430.40  $430.96   12.114161  5216.297064
#
#                      Weighted Price
# Timestamp
# 2015-12-31 19:01:00      430.390768
# 2015-12-31 19:02:00      430.400000
# 2015-12-31 19:03:00      430.382322
# 2015-12-31 19:04:00      430.390000
# 2015-12-31 19:05:00      430.595001

# %%
# Use the str.replace function to remove the dollar sign, $
# YOUR CODE HERE

coinbase_df["Close"] = coinbase_df["Close"].str.replace("$", "")

# %%
# Checking that the $ was removed
coinbase_df.head()
# Out:
#                        Open    High     Low   Close  BTC Volume   USD Volume  \
# Timestamp
# 2015-12-31 19:01:00  430.38  430.40  430.38   430.4    0.947800   407.924370
# 2015-12-31 19:02:00  430.40  430.40  430.40   430.4    1.633400   703.015360
# 2015-12-31 19:03:00  430.39  430.39  430.36  430.36   12.566300  5408.313368
# 2015-12-31 19:04:00  430.39  430.39  430.39  430.39    1.953000   840.551670
# 2015-12-31 19:05:00  430.40  430.96  430.40  430.96   12.114161  5216.297064
#
#                      Weighted Price
# Timestamp
# 2015-12-31 19:01:00      430.390768
# 2015-12-31 19:02:00      430.400000
# 2015-12-31 19:03:00      430.382322
# 2015-12-31 19:04:00      430.390000
# 2015-12-31 19:05:00      430.595001

# %%
# Review the data for duplicate values, and drop them if necessary
# YOUR CODE HERE

coinbase_df.duplicated().sum()
# Out:
# 624

# %%
# Number of duplicate values before the drop.

coinbase_df.drop_duplicates(inplace=True)

# %%
# Checking that the drop has been completed 

coinbase_df.duplicated().sum()
# Out:
# 0

# %%
# Convert the Close data type to a float
# YOUR CODE HERE

coinbase_df["Close"] = coinbase_df["Close"].astype("float")
coinbase_df["Close"].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ## Analyze the Data
#
# Your analysis consists of the following steps:
#
# Your analysis consists of the following tasks:
#
# 1. Choose the columns of data on which to focus your analysis.
#
# 2. Get the summary statistics and plot the data.
#
# 3. Focus your analysis on specific dates.
#
# 4. Calculate the arbitrage profits.

# %% [markdown]
# ### Step 1: Choose columns of data on which to focus your analysis.
#
# Select the data you want to analyze. Use `loc` or `iloc` to select the following columns of data for both the bitstamp and coinbase DataFrames:
#
# * Timestamp (index)
#
# * Close

# %%
# Use loc or iloc to select `Timestamp (the index)` and `Close` from bitstamp DataFrame
bitstamp_sliced = bitstamp_df.iloc[:, [3]]
# Review the first five rows of the DataFrame
# YOUR CODE HERE
bitstamp_sliced.head()
# Out:
#                       Close
# Timestamp
# 2015-12-31 19:01:00  430.89
# 2015-12-31 19:02:00  430.89
# 2015-12-31 19:04:00  431.06
# 2015-12-31 19:05:00  430.54
# 2015-12-31 19:06:00  432.52

# %%
# Use loc or iloc to select `Timestamp (the index)` and `Close` from coinbase DataFrame
coinbase_sliced = coinbase_df.iloc[:,  [3]]


# Review the first five rows of the DataFrame
# YOUR CODE HERE
coinbase_sliced.head()
# Out:
#                       Close
# Timestamp
# 2015-12-31 19:01:00  430.40
# 2015-12-31 19:02:00  430.40
# 2015-12-31 19:03:00  430.36
# 2015-12-31 19:04:00  430.39
# 2015-12-31 19:05:00  430.96

# %% [markdown]
# ### Step 2: Get summary statistics and plot the data.
#
# Sort through the time series data associated with the bitstamp and coinbase DataFrames to identify potential arbitrage opportunities. To do so, complete the following steps:
#
# 1. Generate the summary statistics for each DataFrame by using the `describe` function.
#
# 2. For each DataFrame, create a line plot for the full period of time in the dataset. Be sure to tailor the figure size, title, and color to each visualization.
#
# 3. In one plot, overlay the visualizations that you created in Step 2 for bitstamp and coinbase. Be sure to adjust the legend and title for this new visualization.
#
# 4. Using the `loc` and `plot` functions, plot the price action of the assets on each exchange for different dates and times. Your goal is to evaluate how the spread between the two exchanges changed across the time period that the datasets define. Did the degree of spread change as time progressed?

# %%
# Generate the summary statistics for the bitstamp DataFrame
# YOUR CODE HERE
bitstamp_df.describe()
# Out:
#                Open          High           Low         Close    BTC Volume  \
# count  1.347772e+06  1.347772e+06  1.347772e+06  1.347772e+06  1.347772e+06
# mean   4.503959e+03  4.507642e+03  4.499786e+03  4.503924e+03  7.911510e+00
# std    3.956188e+03  3.960719e+03  3.950903e+03  3.956149e+03  1.986799e+01
# min    3.525600e+02  3.536400e+02  1.500000e+00  1.500000e+00  0.000000e+00
# 25%    7.889100e+02  7.889900e+02  7.888000e+02  7.888900e+02  3.833169e-01
# 50%    3.788730e+03  3.791430e+03  3.786030e+03  3.788990e+03  2.013215e+00
# 75%    6.929362e+03  6.933483e+03  6.924840e+03  6.929443e+03  7.462753e+00
# max    1.966576e+04  1.966600e+04  1.964996e+04  1.966575e+04  1.616060e+03
#
#          USD Volume  Weighted Price
# count  1.347772e+06    1.347772e+06
# mean   3.991326e+04    4.503678e+03
# std    1.171926e+05    3.955833e+03
# min    0.000000e+00    3.521493e+02
# 25%    6.268523e+02    7.888853e+02
# 50%    5.779344e+03    3.788660e+03
# 75%    3.017330e+04    6.929208e+03
# max    5.483271e+06    1.966330e+04

# %%
# Generate the summary statistics for the coinbase DataFrame
# YOUR CODE HERE
coinbase_df.describe()
# Out:
#                Open          High           Low         Close    BTC Volume  \
# count  1.549523e+06  1.549523e+06  1.549523e+06  1.549523e+06  1.549523e+06
# mean   4.091927e+03  4.093727e+03  4.089974e+03  4.091926e+03  8.166907e+00
# std    3.913505e+03  3.915935e+03  3.910917e+03  3.913501e+03  1.837862e+01
# min    6.000000e-02  6.000000e-02  6.000000e-02  6.000000e-02  1.000000e-08
# 25%    6.754400e+02  6.756200e+02  6.751600e+02  6.754000e+02  1.004880e+00
# 50%    2.710690e+03  2.711700e+03  2.709970e+03  2.710730e+03  2.914855e+00
# 75%    6.593500e+03  6.595000e+03  6.591805e+03  6.593500e+03  8.061827e+00
# max    1.989199e+04  1.989199e+04  1.989198e+04  1.989199e+04  1.156319e+03
#
#          USD Volume  Weighted Price
# count  1.549523e+06    1.549523e+06
# mean   4.568889e+04    4.091847e+03
# std    1.575088e+05    3.913428e+03
# min    4.255500e-06    6.000000e-02
# 25%    1.330350e+03    6.753913e+02
# 50%    7.273329e+03    2.710628e+03
# 75%    2.972588e+04    6.593470e+03
# max    1.997076e+07    1.989199e+04

# %%
# Create a line plot for the bitstamp DataFrame for the full length of time in the dataset 
# Be sure that the figure size, title, and color are tailored to each visualization
# YOUR CODE HERE
bitstamp_df.plot(figsize=(16,8), title="Bitstap Full leght Chart.", color='red')
# Out:
# <AxesSubplot:title={'center':'Bitstap Full leght Chart.'}, xlabel='Timestamp'>

# %%
# Create a line plot for the coinbase DataFrame for the full length of time in the dataset 
# Be sure that the figure size, title, and color are tailored to each visualization
# YOUR CODE HERE
coinbase_df.plot(figsize=(16,8), title="Coinbase Full leght Chart.", color='turquoise')
# Out:
# <AxesSubplot:title={'center':'Coinbase Full leght Chart.'}, xlabel='Timestamp'>

# %%
# Overlay the visualizations for the bitstamp and coinbase DataFrames in one plot
# The plot should visualize the prices over the full lenth of the dataset
# Be sure to include the parameters: legend, figure size, title, and color and label
# YOUR CODE HERE

bitstamp_df['Low'].plot(legend=True, figsize=(18, 7), title="Bitstamp and Coinbase DataFrame Overlay Plot Full Lenth of the Dataset", color="red", label="bitstap")
coinbase_df['High'].plot(legend=True, figsize=(18, 7), color="paleturquoise", label="coinbase")
# Out:
# <AxesSubplot:title={'center':'Bitstamp and Coinbase DataFrame Overlay Plot Full Lenth of the Dataset'}, xlabel='Timestamp'>

# %%
# Using the loc and plot functions, create an overlay plot that visualizes 
# the price action of both DataFrames for a one month period early in the dataset
# Be sure to include the parameters: legend, figure size, title, and color and label
# YOUR CODE HERE

bitstamp_df['Close'].loc['2016-06-01':'2016-07-01'].plot(legend=True, figsize=(18, 7), title="Bitstamp and Coinbase One Month Overlay Plot: Early in Dataset", color="red", label="bitstap")
coinbase_df['Close'].loc['2016-06-01':'2016-07-01'].plot(legend=True, figsize=(18, 7), color="turquoise", label="coinbase")
# Out:
# <AxesSubplot:title={'center':'Bitstamp and Coinbase One Month Overlay Plot: Early in Dataset'}, xlabel='Timestamp'>

# %%
# Using the loc and plot functions, create an overlay plot that visualizes 
# the price action of both DataFrames for a one month period later in the dataset
# Be sure to include the parameters: legend, figure size, title, and color and label 
# YOUR CODE HERE
bitstamp_df['Close'].loc['2018-11-11':'2018-12-12'].plot(legend=True, figsize=(16, 8), title="Bitstamp and Coinbase Overlay Plot [One Month Period]: Later in the Dataset", color="red", label="bitstap")
coinbase_df['Close'].loc['2018-11-11':'2018-12-12'].plot(legend=True, figsize=(16, 8), color="turquoise", label="coinbase")
# Out:
# <AxesSubplot:title={'center':'Bitstamp and Coinbase Overlay Plot [One Month Period]: Later in the Dataset'}, xlabel='Timestamp'>

# %% [markdown]
# **Question** Based on the visualizations of the different time periods, has the degree of spread change as time progressed?
#
# **Answer** Based on the evidence I was able to gather from the data. Although not completely extinct, there seems to be a significant decrease in the spread over time. Further specific enquiry into the data may reveal better insight.

# %% [markdown]
# ### Step 3: Focus Your Analysis on Specific Dates
#
# Focus your analysis on specific dates by completing the following steps:
#
# 1. Select three dates to evaluate for arbitrage profitability. Choose one date that’s early in the dataset, one from the middle of the dataset, and one from the last year of the time period.
#
# 2. For each of the three dates, generate the summary statistics and then create a box plot. This big-picture view is meant to help you gain a better understanding of the data before you perform your arbitrage calculations. As you compare the data, what conclusions can you draw?

# %%
# Create an overlay plot that visualizes the two dataframes over a period of one day early in the dataset 
# Be sure that the plots include the parameters `legend`, `figsize`, `title`, `color` and `label` 
# YOUR CODE HERE
bitstamp_df['Close'].loc['2016-06-23'].plot(legend=True, figsize=(20, 8), title="Bitstamp and Coinbase Overlay Plot Period of One Day Early in The Dataset", color="red", label="bitstap")
coinbase_df['Close'].loc['2016-06-23'].plot(legend=True, figsize=(20, 8), color="turquoise", label="coinbase")
# Out:
# <AxesSubplot:title={'center':'Bitstamp and Coinbase Overlay Plot Period of One Day Early in The Dataset'}, xlabel='Timestamp'>

# %%
# Using the early date that you have selected, calculate the arbitrage spread 
# by subtracting the bitstamp lower closing prices from the coinbase higher closing prices
arbitrage_spread_early = coinbase_df['Close'].loc['2016-06-23'] - bitstamp_df['Close'].loc['2016-06-23'] 

# Generate summary statistics for the early DataFrame
# YOUR CODE HERE
arbitrage_spread_early.describe()
# Out:
# count    1295.000000
# mean        7.984510
# std        17.506801
# min        -3.330000
# 25%         3.595000
# 50%         5.940000
# 75%         9.175000
# max       590.300000
# Name: Close, dtype: float64

# %%
# Visualize the arbitrage spread from early in the dataset in a box plot
# Be sure to include at least a title with your plot
# YOUR CODE HERE
arbitrage_spread_early.plot(figsize=(18,10), kind='box', title="Bitstamp and Coinbase Box Plot. Period of One Day Early in The Dataset")
# Out:
# <AxesSubplot:title={'center':'Bitstamp and Coinbase Box Plot. Period of One Day Early in The Dataset'}>

# %%
# Create an overlay plot that visualizes the two dataframes over a period of one day from the middle of the dataset. 
# Be sure that the plots include the parameters `legend`, `figsize`, `title`, `color` and `label` 
# YOUR CODE HERE
bitstamp_df['Close'].loc['2017-10-22'].plot(legend=True, figsize=(16, 8), title="Bitstamp and Coinbase Overlay Plot Period of One Day Middle of the Dataset", color="red", label="bitstap")
coinbase_df['Close'].loc['2017-10-22'].plot(legend=True, figsize=(16, 8), color="turquoise", label="coinbase")
# Out:
# <AxesSubplot:title={'center':'Bitstamp and Coinbase Overlay Plot Period of One Day Middle of the Dataset'}, xlabel='Timestamp'>

# %%
# Using the date form the middle that you have selected, calculate the arbitrage spread 
# by subtracting the bitstamp lower closing prices from the coinbase higher closing prices
arbitrage_spread_middle = coinbase_df['Close'].loc['2017-10-22'] - bitstamp_df['Close'].loc['2017-10-22']

# Generate summary statistics for the middle DataFrame
arbitrage_spread_middle.describe()
# Out:
# count    1401.000000
# mean       20.482491
# std        12.921266
# min       -12.490000
# 25%        11.020000
# 50%        19.530000
# 75%        29.280000
# max        83.240000
# Name: Close, dtype: float64

# %%
# Visualize the arbitrage spread from the middle of the dataset in a box plot
# Be sure to include at least a title with your plot
# YOUR CODE HERE
arbitrage_spread_middle.plot(figsize=(18,10),kind='box',title="Bitstamp and Coinbase Box Plot. Period of One Day Middle of the Dataset")
# Out:
# <AxesSubplot:title={'center':'Bitstamp and Coinbase Box Plot. Period of One Day Middle of the Dataset'}>

# %%
# Create an overlay plot that visualizes the two dataframes over a period of one day from late in the dataset
# Be sure that the plots include the parameters `legend`, `figsize`, `title`, `color` and `label` 
# YOUR CODE HERE
bitstamp_df['Close'].loc['2018-11-13'].plot(legend=True, figsize=(16, 8), title="Bitstamp and Coinbase Overlay Plot Period of One Day Late in the Dataset", color="red", label="bitstap")
coinbase_df['Close'].loc['2018-11-13'].plot(legend=True, figsize=(16, 8), color="turquoise", label="coinbase")
# Out:
# <AxesSubplot:title={'center':'Bitstamp and Coinbase Overlay Plot Period of One Day Late in the Dataset'}, xlabel='Timestamp'>

# %%
# Using th date from late in the dataset that you have selected, calculate the arbitrage spread 
# by subtracting the bitstamp lower closing prices from the coinbase higher closing prices
arbitrage_spread_late = coinbase_df['Close'].loc['2018-11-13'] - bitstamp_df['Close'].loc['2018-11-13']

# Generate summary statistics for the late DataFrame
# YOUR CODE HERE
arbitrage_spread_late.describe()
# Out:
# count    1356.000000
# mean        1.152588
# std         3.388675
# min       -12.600000
# 25%        -1.052500
# 50%         1.200000
# 75%         3.200000
# max        12.950000
# Name: Close, dtype: float64

# %%
# Visualize the arbitrage spread from late in the dataset in a box plot
# Be sure to include at least a title with your plot
# YOUR CODE HERES
arbitrage_spread_late.plot(figsize=(18,10),kind='box', title="Bitstamp and Coinbase Box Plot. Period of One Day Late in the Dataset")
# Out:
# <AxesSubplot:title={'center':'Bitstamp and Coinbase Box Plot. Period of One Day Late in the Dataset'}>

# %% [markdown]
# ### Step 4: Calculate the Arbitrage Profits
#
# Calculate the potential profits for each date that you selected in the previous section. Your goal is to determine whether arbitrage opportunities still exist in the Bitcoin market. Complete the following steps:
#
# 1. For each of the three dates, measure the arbitrage spread between the two exchanges by subtracting the lower-priced exchange from the higher-priced one. Then use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame, where the spread is greater than zero.
#
#
# 2. For each of the three dates, calculate the spread returns. To do so, divide the instances that have a positive arbitrage spread (that is, a spread greater than zero) by the price of Bitcoin from the exchange you’re buying on (that is, the lower-priced exchange). Review the resulting DataFrame.
#
# 3. For each of the three dates, narrow down your trading opportunities even further. To do so, determine the number of times your trades with positive returns exceed the 1% minimum threshold that you need to cover your costs.
#
# 4. Generate the summary statistics of your spread returns that are greater than 1%. How do the average returns compare among the three dates?
#
# 5. For each of the three dates, calculate the potential profit, in dollars, per trade. To do so, multiply the spread returns that were greater than 1% by the cost of what was purchased. Make sure to drop any missing values from the resulting DataFrame.
#
# 6. Generate the summary statistics, and plot the results for each of the three DataFrames.
#
# 7. Calculate the potential arbitrage profits that you can make on each day. To do so, sum the elements in the profit_per_trade DataFrame.
#
# 8. Using the `cumsum` function, plot the cumulative sum of each of the three DataFrames. Can you identify any patterns or trends in the profits across the three time periods?
#
# (NOTE: The starter code displays only one date. You'll want to do this analysis for two additional dates).

# %% [markdown]
# #### 1. For each of the three dates, measure the arbitrage spread between the two exchanges by subtracting the lower-priced exchange from the higher-priced one. Then use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame, where the spread is greater than zero.

# %%
# For the date early in the dataset, measure the arbitrage spread between the two exchanges
# by subtracting the lower-priced exchange from the higher-priced one

arbitrage_spread_early = coinbase_df['Close'].loc['2016-06-23'] - bitstamp_df['Close'].loc['2016-06-23']

arbitrage_spread_early
# Out:
# Timestamp
# 2016-06-23 00:00:00    14.89
# 2016-06-23 00:01:00    16.92
# 2016-06-23 00:02:00    20.60
# 2016-06-23 00:03:00    21.25
# 2016-06-23 00:04:00    17.11
#                        ...
# 2016-06-23 23:55:00    16.00
# 2016-06-23 23:56:00    16.00
# 2016-06-23 23:57:00    18.59
# 2016-06-23 23:58:00    15.01
# 2016-06-23 23:59:00    15.03
# Name: Close, Length: 1439, dtype: float64

# %%
# Use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame
# YOUR CODE HERE

condi_arb_early = arbitrage_spread_early.loc[arbitrage_spread_early > 0].describe()

condi_arb_early
# Out:
# count    1250.000000
# mean        8.315472
# std        17.729642
# min         0.110000
# 25%         3.862500
# 50%         6.140000
# 75%         9.427500
# max       590.300000
# Name: Close, dtype: float64

# %%
# For the from the middle of the dataset, measure the arbitrage spread between the two exchanges
# by subtracting the lower-priced exchange from the higher-priced one

arbitrage_spread_middle = coinbase_df['Close'].loc['2017-10-22'] - bitstamp_df['Close'].loc['2017-10-22']

arbitrage_spread_middle
# Out:
# Timestamp
# 2017-10-22 00:00:00    28.37
# 2017-10-22 00:01:00    36.39
# 2017-10-22 00:02:00    44.21
# 2017-10-22 00:03:00    46.16
# 2017-10-22 00:04:00    66.07
#                        ...
# 2017-10-22 23:55:00    24.37
# 2017-10-22 23:56:00    14.92
# 2017-10-22 23:57:00    26.26
# 2017-10-22 23:58:00    26.42
# 2017-10-22 23:59:00    22.16
# Name: Close, Length: 1440, dtype: float64

# %%
# Use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame
# YOUR CODE HERE

condi_arb_middle = arbitrage_spread_middle.loc[arbitrage_spread_middle > 0].describe()

condi_arb_middle
# Out:
# count    1353.000000
# mean       21.367679
# std        12.231643
# min         0.180000
# 25%        11.900000
# 50%        19.990000
# 75%        29.700000
# max        83.240000
# Name: Close, dtype: float64

# %%
# For the date late in the dataset, measure the arbitrage spread between the two exchanges
# by subtracting the lower-priced exchange from the higher-priced one

arbitrage_spread_late = coinbase_df['Close'].loc['2018-11-13'] - bitstamp_df['Close'].loc['2018-11-13']

arbitrage_spread_late
# Out:
# Timestamp
# 2018-11-13 00:00:00    4.99
# 2018-11-13 00:01:00    4.99
# 2018-11-13 00:02:00    4.98
# 2018-11-13 00:03:00    5.01
# 2018-11-13 00:04:00    7.77
#                        ...
# 2018-11-13 23:55:00   -0.50
# 2018-11-13 23:56:00   -2.00
# 2018-11-13 23:57:00   -2.66
# 2018-11-13 23:58:00   -0.87
# 2018-11-13 23:59:00    0.25
# Name: Close, Length: 1440, dtype: float64

# %%
# Use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame
# YOUR CODE HERE

codi_arb_late = arbitrage_spread_late.loc[arbitrage_spread_late > 0].describe()

codi_arb_late
# Out:
# count    887.000000
# mean       3.024735
# std        2.342220
# min        0.020000
# 25%        1.320000
# 50%        2.610000
# 75%        4.290000
# max       12.950000
# Name: Close, dtype: float64

# %% [markdown]
# #### 2. For each of the three dates, calculate the spread returns. To do so, divide the instances that have a positive arbitrage spread (that is, a spread greater than zero) by the price of Bitcoin from the exchange you’re buying on (that is, the lower-priced exchange). Review the resulting DataFrame.

# %%
# For the date early in the dataset, calculate the spread returns by dividing 
# the instances when the arbitrage spread is positive (> 0) by the price of Bitcoin 
# from the exchange you are buying on (the lower-priced exchange)

btc_early_mean = bitstamp_df['Close'].loc['2016-06-23'].mean()

btc_early_mean
# Out:
# 600.2989976869696

# %%
# For the date in the middle of the dataset, calculate the spread returns by dividing 
# the instances when the arbitrage spread is positive (> 0)  by the price of Bitcoin 
# from the exchange you are buying on (the lower-priced exchange)

btc_mid_mean = bitstamp_df['Close'].loc['2017-10-22'].mean()

btc_mid_mean
# Out:
# 5904.641884368306

# %%
# For the date in the middle of the dataset, calculate the spread returns by dividing 
# the instances when the arbitrage spread is positive (> 0)  by the price of Bitcoin 
# from the exchange you are buying on (the lower-priced exchange)

btc_late_mean = bitstamp_df['Close'].loc['2018-11-13'].mean()

btc_late_mean
# Out:
# 6282.328783185841

# %%
# For the date early in the dataset, calculate the spread returns by dividing 
# the instances when the arbitrage spread is positive (> 0) by the price of Bitcoin 
# from the exchange you are buying on (the lower-priced exchange)

spread_return_early = arbitrage_spread_early / btc_early_mean

# Review the spread return DataFrame
# YOUR CODE HERE
spread_return_early.head()
# Out:
# Timestamp
# 2016-06-23 00:00:00    0.024804
# 2016-06-23 00:01:00    0.028186
# 2016-06-23 00:02:00    0.034316
# 2016-06-23 00:03:00    0.035399
# 2016-06-23 00:04:00    0.028502
# Name: Close, dtype: float64

# %%
# For the date in the middle of the dataset, calculate the spread returns by dividing 
# the instances when the arbitrage spread is positive (> 0)  by the price of Bitcoin 
# from the exchange you are buying on (the lower-priced exchange)

spread_return_middle = arbitrage_spread_middle / btc_mid_mean

# Review the spread return DataFrame
# YOUR CODE HERE
spread_return_middle.head()
# Out:
# Timestamp
# 2017-10-22 00:00:00    0.004805
# 2017-10-22 00:01:00    0.006163
# 2017-10-22 00:02:00    0.007487
# 2017-10-22 00:03:00    0.007818
# 2017-10-22 00:04:00    0.011190
# Name: Close, dtype: float64

# %%
# For the date late in the dataset, calculate the spread returns by dividing 
# the instances when the arbitrage spread is positive (> 0)  by the price of Bitcoin 
# from the exchange you are buying on (the lower-priced exchange)

spread_return_late = arbitrage_spread_late / btc_late_mean

# Review the spread return DataFrame
spread_return_late.head()
# Out:
# Timestamp
# 2018-11-13 00:00:00    0.000794
# 2018-11-13 00:01:00    0.000794
# 2018-11-13 00:02:00    0.000793
# 2018-11-13 00:03:00    0.000797
# 2018-11-13 00:04:00    0.001237
# Name: Close, dtype: float64

# %% [markdown]
# #### 3. For each of the three dates, narrow down your trading opportunities even further. To do so, determine the number of times your trades with positive returns exceed the 1% minimum threshold that you need to cover your costs.

# %%
# For the date early in the dataset, determine the number of times your trades with positive returns 
# exceed the 1% minimum threshold (.01) that you need to cover your costs

profitable_trades_early = spread_return_early[spread_return_early > .01]

# Review the first five profitable trades
# YOUR CODE HERE
profitable_trades_early.head()
# Out:
# Timestamp
# 2016-06-23 00:00:00    0.024804
# 2016-06-23 00:01:00    0.028186
# 2016-06-23 00:02:00    0.034316
# 2016-06-23 00:03:00    0.035399
# 2016-06-23 00:04:00    0.028502
# Name: Close, dtype: float64

# %%
# For the date in the middle of the dataset, determine the number of times your trades with positive returns 
# exceed the 1% minimum threshold (.01) that you need to cover your costs

profitable_trades_middle = spread_return_middle[spread_return_middle > .01]

# Review the first five profitable trades
profitable_trades_middle.head()
# Out:
# Timestamp
# 2017-10-22 00:04:00    0.011190
# 2017-10-22 00:05:00    0.010278
# 2017-10-22 00:07:00    0.012875
# 2017-10-22 00:08:00    0.011503
# 2017-10-22 00:11:00    0.010006
# Name: Close, dtype: float64

# %%
# For the date late in the dataset, determine the number of times your trades with positive returns 
# exceed the 1% minimum threshold (.01) that you need to cover your costs

profitable_trades_late = spread_return_late[spread_return_late > .01]

# Review the first five profitable trades
# YOUR CODE HERE
profitable_trades_late.head()
# Out:
# Series([], Name: Close, dtype: float64)

# %%
#### 4. Generate the summary statistics of your spread returns that are greater than 1%. How do the average returns compare among the three dates?

# %%
# For the date early in the dataset, generate the summary statistics for the profitable trades
# or you trades where the spread returns are are greater than 1%

profitable_trades_early_sum = profitable_trades_early[profitable_trades_early > .01]

profitable_trades_early_sum.describe()
# Out:
# count    636.000000
# mean       0.021366
# std        0.039927
# min        0.010028
# 25%        0.012540
# 50%        0.015534
# 75%        0.024142
# max        0.983343
# Name: Close, dtype: float64

# %%
# For the date in the middle of the dataset, generate the summary statistics for the profitable trades
# or you trades where the spread returns are are greater than 1%
# YOUR CODE HERE
profitable_trades_sum_mid = profitable_trades_middle[profitable_trades_middle > .01]

profitable_trades_sum_mid.describe()
# Out:
# count    9.000000
# mean     0.011771
# std      0.001429
# min      0.010006
# 25%      0.010470
# 50%      0.011503
# 75%      0.012875
# max      0.014097
# Name: Close, dtype: float64

# %%
# For the date late in the dataset, generate the summary statistics for the profitable trades
# or you trades where the spread returns are are greater than 1%
# YOUR CODE HERE
profitable_trades_sum_late = profitable_trades_late[profitable_trades_late > .01]

profitable_trades_sum_late.describe()
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Close, dtype: float64

# %% [markdown]
# #### 5. For each of the three dates, calculate the potential profit, in dollars, per trade. To do so, multiply the spread returns that were greater than 1% by the cost of what was purchased. Make sure to drop any missing values from the resulting DataFrame.

# %% [markdown]
# profitable_trades_early

# %%
# For the date early in the dataset, calculate the potential profit per trade in dollars 
# Multiply the profitable trades by the cost of the Bitcoin that was purchased

profit_early =  profitable_trades_early * btc_early_mean

profit_early
# Out:
# Timestamp
# 2016-06-23 00:00:00    14.89
# 2016-06-23 00:01:00    16.92
# 2016-06-23 00:02:00    20.60
# 2016-06-23 00:03:00    21.25
# 2016-06-23 00:04:00    17.11
#                        ...
# 2016-06-23 23:55:00    16.00
# 2016-06-23 23:56:00    16.00
# 2016-06-23 23:57:00    18.59
# 2016-06-23 23:58:00    15.01
# 2016-06-23 23:59:00    15.03
# Name: Close, Length: 636, dtype: float64

# %%
# Drop any missing values from the profit DataFrame

profit_early.dropna(inplace=True)

# %%
# View the early profit DataFrame
# YOUR CODE HERE

profit_per_trade_early = profit_early

profit_per_trade_early
# Out:
# Timestamp
# 2016-06-23 00:00:00    14.89
# 2016-06-23 00:01:00    16.92
# 2016-06-23 00:02:00    20.60
# 2016-06-23 00:03:00    21.25
# 2016-06-23 00:04:00    17.11
#                        ...
# 2016-06-23 23:55:00    16.00
# 2016-06-23 23:56:00    16.00
# 2016-06-23 23:57:00    18.59
# 2016-06-23 23:58:00    15.01
# 2016-06-23 23:59:00    15.03
# Name: Close, Length: 636, dtype: float64

# %%
# For the date in the middle of the dataset, calculate the potential profit per trade in dollars 
# Multiply the profitable trades by the cost of the Bitcoin that was purchased

profit_middle = profitable_trades_sum_mid * btc_mid_mean

profit_middle
# Out:
# Timestamp
# 2017-10-22 00:04:00    66.07
# 2017-10-22 00:05:00    60.69
# 2017-10-22 00:07:00    76.02
# 2017-10-22 00:08:00    67.92
# 2017-10-22 00:11:00    59.08
# 2017-10-22 00:12:00    77.59
# 2017-10-22 00:15:00    83.24
# 2017-10-22 00:17:00    61.82
# 2017-10-22 07:08:00    73.11
# Name: Close, dtype: float64

# %%
# Drop any missing values from the profit DataFrame

profit_middle.dropna(inplace=True)

# %%
# View the early profit DataFrame

profit_per_trade_middle = profit_middle

profit_per_trade_middle
# Out:
# Timestamp
# 2017-10-22 00:04:00    66.07
# 2017-10-22 00:05:00    60.69
# 2017-10-22 00:07:00    76.02
# 2017-10-22 00:08:00    67.92
# 2017-10-22 00:11:00    59.08
# 2017-10-22 00:12:00    77.59
# 2017-10-22 00:15:00    83.24
# 2017-10-22 00:17:00    61.82
# 2017-10-22 07:08:00    73.11
# Name: Close, dtype: float64

# %%
# For the date late in the dataset, calculate the potential profit per trade in dollars 
# Multiply the profitable trades by the cost of the Bitcoin that was purchased

profit_late = profitable_trades_sum_late * btc_late_mean

# %%
# Drop any missing values from the profit DataFrame

profit_late.dropna(inplace=True)

# %%
# View the early profit DataFrame
# YOUR CODE HERE

profit_per_trade_late = profit_late

profit_per_trade_late
# Out:
# Series([], Name: Close, dtype: float64)

# %% [markdown]
# #### 6. Generate the summary statistics, and plot the results for each of the three DataFrames.

# %%
# Generate the summary statistics for the early profit per trade DataFrame
# YOUR CODE HERE
profit_per_trade_early.describe()
# Out:
# count    636.000000
# mean      12.826258
# std       23.968158
# min        6.020000
# 25%        7.527500
# 50%        9.325000
# 75%       14.492500
# max      590.300000
# Name: Close, dtype: float64

# %%
profit_per_trade_early.explode()
# Out:
# Timestamp
# 2016-06-23 00:00:00    14.89
# 2016-06-23 00:01:00    16.92
# 2016-06-23 00:02:00    20.60
# 2016-06-23 00:03:00    21.25
# 2016-06-23 00:04:00    17.11
#                        ...
# 2016-06-23 23:55:00    16.00
# 2016-06-23 23:56:00    16.00
# 2016-06-23 23:57:00    18.59
# 2016-06-23 23:58:00    15.01
# 2016-06-23 23:59:00    15.03
# Name: Close, Length: 636, dtype: float64

# %%
bitstamp_df['Close'].loc['2016-06-23'].plot(legend=True, figsize=(20, 8), title="Bitstamp and Coinbase Overlay Plot Period of One Day Early in The Dataset", color="red", label="bitstap")
# Out:
# <AxesSubplot:title={'center':'Bitstamp and Coinbase Overlay Plot Period of One Day Early in The Dataset'}, xlabel='Timestamp'>

# %%
# Plot the results for the early profit per trade DataFrame
# Be sure to include at least a title with your plot
# YOUR CODE HERE
profit_per_trade_early.plot(legend=True, figsize=(16, 8), title= "Results For The Early Profit Per Trade DataFrame")
# Out:
# <AxesSubplot:title={'center':'Results For The Early Profit Per Trade DataFrame'}, xlabel='Timestamp'>

# %%
# Generate the summary statistics for the middle profit per trade DataFrame
# YOUR CODE HERE
profit_per_trade_middle.describe()
# Out:
# count     9.000000
# mean     69.504444
# std       8.435151
# min      59.080000
# 25%      61.820000
# 50%      67.920000
# 75%      76.020000
# max      83.240000
# Name: Close, dtype: float64

# %%
profit_per_trade_middle.explode()
# Out:
# Timestamp
# 2017-10-22 00:04:00    66.07
# 2017-10-22 00:05:00    60.69
# 2017-10-22 00:07:00    76.02
# 2017-10-22 00:08:00    67.92
# 2017-10-22 00:11:00    59.08
# 2017-10-22 00:12:00    77.59
# 2017-10-22 00:15:00    83.24
# 2017-10-22 00:17:00    61.82
# 2017-10-22 07:08:00    73.11
# Name: Close, dtype: float64

# %%
# Plot the results for the middle profit per trade DataFrame
# Be sure to include at least a title with your plot
# YOUR CODE HERE
profit_per_trade_middle.plot(legend=True, figsize=(16, 8), title= "Results For The Middle Profit Per Trade DataFrame")
# Out:
# <AxesSubplot:title={'center':'Results For The Middle Profit Per Trade DataFrame'}, xlabel='Timestamp'>

# %%
# Generate the summary statistics for the late profit per trade DataFrame
# YOUR CODE HERE
profit_per_trade_late.describe()
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Close, dtype: float64

# %%
profitable_trades_late.explode()
# Out:
# Series([], Name: Close, dtype: float64)

# %%
# Plot the results for the late profit per trade DataFrame
# Be sure to include at least a title with your plot
# YOUR CODE HERE
profitable_trades_late.plot(legend=True, figsize=(16, 8), title= "Results For The Late Profit Per Trade DataFrame")
# Out:
# <AxesSubplot:title={'center':'Results For The Late Profit Per Trade DataFrame'}, xlabel='Timestamp'>

# %% [markdown]
# #### 7. Calculate the potential arbitrage profits that you can make on each day. To do so, sum the elements in the profit_per_trade DataFrame.

# %%
# Calculate the sum of the potential profits for the early profit per trade DataFrame
# YOUR CODE HERE
potential_profits_early_data = profit_per_trade_early.sum()
#potential_profits_early_data.dtype

# %%
potential_profits_early_data
# Out:
# 8157.499999999999

# %%
# Calculate the sum of the potential profits for the middle profit per trade DataFrame
# YOUR CODE HERE
potential_profits_mid_data = profit_per_trade_middle.sum()
potential_profits_mid_data.dtype
# Out:
# dtype('float64')

# %%
potential_profits_mid_data
# Out:
# 625.54

# %%
# Calculate the sum of the potential profits for the late profit per trade DataFrame
# YOUR CODE HERE
potential_profits_late_data = profitable_trades_late.sum()
potential_profits_late_data.dtype
# Out:
# dtype('float64')

# %%
potential_profits_late_data
# Out:
# 0.0

# %% [markdown]
# #### 8. Using the `cumsum` function, plot the cumulative sum of each of the three DataFrames. Can you identify any patterns or trends in the profits across the three time periods?

# %%
# Use the cumsum function to calculate the cumulative profits over time for the early profit per trade DataFrame
cumulative_profit_early = profit_per_trade_early.cumsum()
cumulative_profit_early
# Out:
# Timestamp
# 2016-06-23 00:00:00      14.89
# 2016-06-23 00:01:00      31.81
# 2016-06-23 00:02:00      52.41
# 2016-06-23 00:03:00      73.66
# 2016-06-23 00:04:00      90.77
#                         ...
# 2016-06-23 23:55:00    8092.87
# 2016-06-23 23:56:00    8108.87
# 2016-06-23 23:57:00    8127.46
# 2016-06-23 23:58:00    8142.47
# 2016-06-23 23:59:00    8157.50
# Name: Close, Length: 636, dtype: float64

# %%
profitable_trades_late.plot(legend=True, figsize=(16, 8), title= "Results For The Late Profit Per Trade DataFrame")
# Out:
# <AxesSubplot:title={'center':'Results For The Late Profit Per Trade DataFrame'}, xlabel='Timestamp'>

# %%
# Plot the cumulative sum of profits for the early profit per trade DataFrame
# Be sure to include at least a title with your plot
# YOUR CODE HERE
cumulative_profit_early.plot(legend=True, figsize=(16, 8), title= "Cumulative Sum of Profits For The Early Profit Per Trade DataFrame")
# Out:
# <AxesSubplot:title={'center':'Cumulative Sum of Profits For The Early Profit Per Trade DataFrame'}, xlabel='Timestamp'>

# %%
# Use the cumsum function to calculate the cumulative profits over time for the middle profit per trade DataFrame
cumulative_profit_middle = profit_per_trade_middle.cumsum()
cumulative_profit_middle
# Out:
# Timestamp
# 2017-10-22 00:04:00     66.07
# 2017-10-22 00:05:00    126.76
# 2017-10-22 00:07:00    202.78
# 2017-10-22 00:08:00    270.70
# 2017-10-22 00:11:00    329.78
# 2017-10-22 00:12:00    407.37
# 2017-10-22 00:15:00    490.61
# 2017-10-22 00:17:00    552.43
# 2017-10-22 07:08:00    625.54
# Name: Close, dtype: float64

# %%
# Plot the cumulative sum of profits for the midle profit per trade DataFrame
# Be sure to include at least a title with your plot
# YOUR CODE HERE
cumulative_profit_middle.plot(legend=True, figsize=(16, 8), title= "Cumulative Sum of Profits For The Midle Profit Per Trade DataFrame")
# Out:
# <AxesSubplot:title={'center':'Cumulative Sum of Profits For The Midle Profit Per Trade DataFrame'}, xlabel='Timestamp'>

# %%
# Use the cumsum function to calculate the cumulative profits over time for the late profit per trade DataFrame

cumulative_profit_late = profit_per_trade_late.cumsum()
cumulative_profit_late
# Out:
# Series([], Name: Close, dtype: float64)

# %%
# Plot the cumulative sum of profits for the late profit per trade DataFrame
# Be sure to include at least a title with your plot
# YOUR CODE HERE
cumulative_profit_late.plot(legend=True, figsize=(16, 8), title= "Cumulative Sum of Profits For The Late Profit Per Trade DataFrame")
# Out:
# <AxesSubplot:title={'center':'Cumulative Sum of Profits For The Late Profit Per Trade DataFrame'}, xlabel='Timestamp'>

# %% [markdown]
# **Question:** After reviewing the profit information across each date from the different time periods, can you identify any patterns or trends?
#
# **Answer:** Arbitrage profits are extremely hard to come by at the market for Bitcoin matures across time. As Bitcoin grows in populatiry, the prices across the two exhanges trade more in line with one another. That makes is very difficult find a point where the price difference exceeds the minimum profit threshold of 1%. Although times existed were big arbitrage opportunities were common place among these mentioned exchanges those opportunities are not better categorized as prehistoric.

# %% [markdown]
# ## Analysis Report

# %%
 #Although times existed were big arbitrage opportunities were common place among these mentioned exchanges

# %%
# The Following chart shows one of the largest discrepancies in the entire data set over two months.

# %%
two_months = coinbase_df['Close'].loc['2016-06-01':'2016-08-01'] - bitstamp_df['Close'].loc['2016-06-01':'2016-08-01']
two_months.loc[two_months > 0.1].describe()
# Out:
# count    46528.000000
# mean         4.043611
# std          4.653907
# min          0.100000
# 25%          1.670000
# 50%          3.030000
# 75%          4.980000
# max        590.300000
# Name: Close, dtype: float64

# %%
two_months.plot(legend=True, figsize=(16, 8), title = "High Arbitrage Times")
# Out:
# <AxesSubplot:title={'center':'High Arbitrage Times'}, xlabel='Timestamp'>

# %%
#Where we see the lasr of the opportunites go

# %%
one_year_half = coinbase_df['Close'].loc['2017-06-13':'2018-12-23'] - bitstamp_df['Close'].loc['2017-06-13':'2018-12-23']
one_year_half.loc[one_year_half > .01].describe()
# Out:
# count    421514.000000
# mean         40.972481
# std         119.539234
# min           0.010000
# 25%           2.670000
# 50%           6.680000
# 75%          19.470000
# max        3509.990000
# Name: Close, dtype: float64

# %%
one_year_half.plot(legend=True, figsize=(16, 8), title = "High Arbitrage Times")
# Out:
# <AxesSubplot:title={'center':'High Arbitrage Times'}, xlabel='Timestamp'>
